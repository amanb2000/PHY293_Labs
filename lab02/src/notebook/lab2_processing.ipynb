# %%
from pickle import load as pkl_load
import matplotlib.pyplot as plt
import numpy as np

# required for successful run of other cells

# preload data
PATH_DATA = "lab02/data/readings.pkl"
dataFile = open(PATH_DATA, "rb")
# primary data object-dictionary
data = pkl_load(dataFile)
dataFile.close()

# useful enums for data dict key
DAY1 = "day1"
DAY2 = "day2"
# note, each day in the dict does not contain the same number of data sets

# %%
print("Days:", len(data))
print("Samples in DAY1:", len(data[DAY1]))
print("Samples in DAY2:", len(data[DAY2]))
# Out:
# 2
# 27
# 32
